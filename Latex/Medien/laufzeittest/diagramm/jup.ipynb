# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data for plotting

i = [17,18, 19,20,21,22, 23,24]
tango = [2, 3, 8, 21, 45, 140, 258, 457]
splay = [0, 0, 0, 2, 6, 12, 20, 35]
plt.xlabel('l')
plt.ylabel('Zeit(s)')
plt.plot(i, tango, "r-",
         i, tango, "dr",
         i, splay, "b-",
         i, splay, "db")
plt.savefig("test.png")

# %%
i = [17,18, 19,20,21,22, 23,24]
tango = [2, 3, 8, 21, 45, 140, 258, 457]
splay = [0, 0, 0, 2, 6, 12, 20, 35]

fig, axs = plt.subplots(2, 1)
axs[0].plot(i, tango, i, splay)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)
plt.show()
fig.savefig("test.png")
